# %%
a = 3
lst= [2,3,45] # yes or no ?? mutable or immutable
test = (2,3,4) # yes or no ??

# how define ?? ?? 
for i in a:
    print(i)
# Out:
# 3

# %%
# 1000 function --> how they will use lambda ??

# %%
def negative_int(lst):
    output = []
    for i in lst:
        if i<0:
            output.append(i)
    return output
        
data = [32,-2,-4,-3,2,1,0]
negative_int(data)
# Out:
# [-2, -4, -3]

# %%
data = [32,-2,-4,-3,2,1,0]
output = []
for i in data:
    if i<0:
        output.append(i**2)

print(output)
# Out:
# [4, 16, 9]

# %%
def sqre_neg(data):
    output = []
    for i in data:
        if i<0:
            output.append(i**2)
    return output


sqre_neg([-1,-2,-3,-4,-5])
# Out:
# [1, 4, 9, 16, 25]

# %%
abc = [23,34,56,76,87,89,101,103,104]

data[0:4]  # slicing of list
data[1::2] # slicing of list

odd_day_avg_sales = sum(abc[1::2])/len(abc[1::2])
# Out:
# 75.5

# %%
def odd_days_sales(data):
    odd_day_avg_sales = sum(data[1::2])/len(data[1::2])
    return odd_day_avg_sales




sum(odd_days_sales) # why ?? why you can pass

# questions ??
# what are the parameter ??
# sum --> inbuilt --> parameter ?? int?? documentations ?? 
sum([1,2,3])
# Out:
# 75.5

# %%
filter() # documentations

# %%
for i in data:
    if i<0:
        print(i)
# Out:
# -3

# %%
sum(sales_data)

# %%
# from test import square


def sales_data(x):
    return x>32


data = [32,23,33]

list(filter(sales_data, data))
# how many parameter ?? --> rahul
# what type of parameter ?? --> rahul
# what is the return type ?? --> rahul
# Out:
# [33]

# %%
def sqre_neg(data):
    output = []
    for i in data:
        if i<0:
            output.append(i**2)
    return output

# %%
def sqre_neg(data):
    if data<0:
        return True
    return False

# %%
data =[23,24,34,-20]

# %%
list(filter(sqre_neg, data))
# Out:
# [-20]

# %%
data = [32,23,33]
list(filter(lambda x: x>32, data))
# Out:
# [33]

# %%
sqre = lambda x: x*x
sqre(2)
# Out:
# 4

# %%
lst = [2,3,5,6,7,9,10]
list(filter(lambda num:num%2==0,lst))
# https://docs.python.org/3/library/functions.html


# final_output = []
# for i in lst:
#     if even(i):
#         final_output.append(i)
    
# final_output
# Out:
# [2, 6, 10]

# %%
import numpy as np
x = np.random.randint(0, 100, 5000)
x
# Out:
# array([76, 16,  6, ..., 92, 30, 24], shape=(5000,))

# %%
data = [12,23,3,4,5,34,34,45,45,12]
import time
start_time = time.time()
count = 0
for i in x:
    if i>34:
        count += 1

end_time = time.time()
print(f"Time taken: {end_time - start_time} seconds")
# Out:
# Time taken: 0.00030994415283203125 seconds

# %%
lst = [1, 2, 3, 4, 5]


list(map(lambda x: x**2, lst))
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# In Python, anonymous function is a function that is defined without a name.
#
# While normal functions are defined using the def keyword, in Python anonymous functions are defined using the lambda keyword.
#
# Lambda functions are used extensively along with built-in functions like filter(), map()

# %% [markdown]
# syntax:
#
#     lambda arguments: expression

# %%
# eg
test = lambda x,y: x+y

test(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 # eg
#       2 test = lambda x,y: x+y
#       3
# ----> 4 test(2)
#
# TypeError: <lambda>() missing 1 required positional argument: 'y'
