# %% [markdown]
# ## Function basics

# %%
from utils import sales_avg

sales_data = {
   'day_1':[100, 200, 300],
   'day_2':[150, 250, 350],
   'day_3':[200, 300, 400],
   'day_4':[250, 350, 450],
   'day_5':[12]

}

output = sales_avg(sales_data)
print(output)


# simple cmd to run --> shift + enter
# Out:
# {'day_1': 200.0, 'day_2': 250.0, 'day_3': 300.0, 'day_4': 350.0, 'day_5': 12.0}
